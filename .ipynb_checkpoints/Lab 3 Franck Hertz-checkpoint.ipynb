# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.optimize import curve_fit
from scipy.stats import norm

# %%
#import data for general plot
runs1 = pd.read_csv("data/run1.csv", sep = ";")
runs2 = ["data/run2.csv"]
runs3 = pd.read_csv("data/run3.csv", sep = ";")
runs4 = pd.read_csv("data/run4.csv", sep = ";")

for run in runs1:
    voltage1 = runs1["Voltage (V)"].to_numpy()
    current_n1 = runs1["Current (A)"].to_numpy()
current1 = (-1)*current_n1

for run in runs2:
    voltage2 = pd.read_csv(run)["Voltage (V)"].to_numpy()
    current_n2 = pd.read_csv(run)["Current (A)"].to_numpy()
current2 = (-1)*current_n2

for run in runs3:
    voltage3 = runs3["Voltage (V)"].to_numpy()
    current_n3 = runs3["Current (A)"].to_numpy()
current3 = (-1)*current_n3

for run in runs4:
    voltage4 = runs4["Voltage (V)"].to_numpy()
    current_n4 = runs4["Current (A)"].to_numpy()
current4 = (-1)*current_n4

# %%
'''#need to find averages, std and sem 

def stats_current(key):
    return (np.mean(current.get(key), np.std(current.get(key),
                        np.std(current.get(key)/np.sqrt(len(current.get(key)))

stats = { "u_current1" : stats_current(      '''
# Out:
#   Cell In[13], line 5
#     np.std(current.get(key)/np.sqrt(len(current.get(key)))
#            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
#plot current against voltage

plt.figure()
plt.plot(voltage4, current4)
plt.xlabel("Voltage (V)")
plt.ylabel("Current (A)")
plt.title("Current as a function of voltage")
plt.grid()
plt.show()

# %%
#extracting 5 minimas

windows = [25, 33, 45, 57, 68, 79]

voltage_min, current_min = [], []

for i in range(5):
    mask = (voltage >= windows[i]) & (voltage < windows[i+1])
    idx = np.argmin(current[mask])
    voltage_min.append(voltage[mask][idx])
    current_min.append(current[mask][idx])
    
print(voltage_min, current_min)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 8
#       5 voltage_min, current_min = [], []
#       7 for i in range(5):
# ----> 8     mask = (voltage >= windows[i]) & (voltage < windows[i+1])
#       9     idx = np.argmin(current[mask])
#      10     voltage_min.append(voltage[mask][idx])
#
# NameError: name 'voltage' is not defined

# %%
print(voltage_min[1]-voltage_min[0])
print(voltage_min[2]-voltage_min[1])
print(voltage_min[3]-voltage_min[2])
print(voltage_min[4]-voltage_min[3])
# Out:
# 11.816000000000003
# 11.445999999999998
# 11.329
# 11.803000000000004
